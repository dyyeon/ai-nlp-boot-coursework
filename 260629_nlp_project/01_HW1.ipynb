# %% [markdown]
# 다음 수순을 따라 NLP 프로젝트를 진행하십시오.
# NLTK 데이터를 학습 데이터와 테스트 데이터 각각 9:1로 분리합니다.
# 학습 데이터를 Train 데이터와 Validation 데이터로 각각 8:2로 분리합니다.
# 학습데이터를 토대로 SentencePiece를 이용하여 단어사전을 만든 후 토큰화 합니다.
# 2에서 만든 단어사전을 통해 테스트 데이터를 토큰화 합니다.
# 각각에 padding을 추가하여 torch dataset으로 만듭니다.
# dataloader를 만듭니다.
# 다음과 같은 구조를 가진 모델을 생성합니다.
# embedding layer(입력층)-RNN-출력층
# 모델을 학습합니다.
# 모델을 평가합니다.
# 위에서 입력이 필요한 파라미터는 다음과 같습니다.
# Vocab 크기
# 데이터의 최대 길이(문장의 길이)
# Embedding layer의 차원수(단어의 벡터 길이)
# RNN hidden state의 크기(컨텍스트 벡터의 길이)
# 출력층 구조 및 최종 아웃풋
